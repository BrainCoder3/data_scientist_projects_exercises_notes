# %% [markdown]
# we can use the plt.barh() mthod to draw our bar horizontally

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# def clean_bar_axes( ):
#     ax = plt.gca() # get current axis
#     ax.spines[['top','bottom','left','right']].set_visible(False)#remove axises
#     ax.grid(axis='x', color='black', alpha=0.5)#add and horizontal or vertical bar , and alpha control the opacity
#     ax.tick_params(axis='both', length=0)#to make it look bold

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# we have also the df.loc[] method , that allow us to get a specific row , by its name , and if this row doesn't exist , it creat it

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# the perfect way to visulize paired data is scatter plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# plt.xlim(0,100) et plt.ylim(0,100)
# allow to draw a and axix y=x
#
#
# ax.set_aspect(1) allow us to redimension
#
# the alpha parameter permit to control the transparancy

# %%
plt.text(x,y,label) allow to insert some label at some elements
