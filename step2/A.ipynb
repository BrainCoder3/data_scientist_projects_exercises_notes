# %% [markdown]
# we also have the function rename that permit us to rename some columns this takes a columns with the old name as the key and the new name as the value

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# we have the to_datetime(series) that permit to trnsform a series in a datetime type , for example if i want the year
#
# df.to_datetime(series).dt.year

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# we can use dt.total_secon() to get the time in seconds

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# we have also dt.strftime('%d') which allow us to find the day , and %m for the month , %y for the year , %a give the name of the day

# %% [markdown]
# there is the reindex(list_index) that allow us to change the order of our indexes with the order of list_index

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# the subset method is used to drop nan values but on a specific column
