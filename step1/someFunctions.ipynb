# %% [markdown]
# we can use the method eval , if we want to create a new column thanks to a formula
# for example, if i want to create a new column in the df dataframe , i will
# df['area']=df.eval('1/2 * base * height') with base and height some column names in my dataframe df

# %% [markdown]
# we also have the query method , wich help us to find the row,we want , in our dataFrame
#
# for example if I want the the month which have the number of days over 30 , I can write
# df['months'].query('days >30') with months and days some columns in our datFrame df

# %% [markdown]
# we have to groupBy method that permit us to group our dataFrame by something , one column, its different values and to to some calculations on it
#
#
# df.groupBy("'fruits)['weight'].mean().reset_index()
#
# with reset_index() we transform our output into a DataFrame

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# we also have the merge method ,which allow us to merge two dataFrame
#
# for exmample:
# df=data1.merge(data2,on="similarity",how="left or right")

# %% [markdown]
# ![merge.png](images/merge.png)

# %% [markdown]
# we also have axhline(50) wich plot a line a 50% and horizontal

# %%
![axhline](images/axhline.png)
# Out:
# '[axhline]' is not recognized as an internal or external command,
# operable program or batch file.
